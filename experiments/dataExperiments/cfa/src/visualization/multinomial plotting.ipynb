# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import pandas as pd
import numpy as np

mpl.rcParams.update({'font.size': 22, 'lines.linewidth': 3, 'lines.markersize': 15, 'font.family': 'Times New Roman'})
    # avoid type 3 (i.e. bitmap) fonts in figures
mpl.rcParams['ps.useafm'] = True
mpl.rcParams['pdf.use14corefonts'] = True
mpl.rcParams['text.usetex'] = True

data = pd.read_csv('FailprobIncreaseWithK_030303_01.csv')
x = data['x']
y = data['y']

data2 = pd.read_csv('FailprobIncreaseWithK_020503_01.csv')
x2 = data2['x']
y2 = data2['y']

data3 = pd.read_csv('FailprobIncreaseWithK_025025025025_01.csv')
x3 = data3['x']
y3 = data3['y']

data4 = pd.read_csv('FailprobIncreaseWithK_060202_01.csv')
x4 = data4['x']
y4 = data4['y']
_, ax = plt.subplots()
ax.plot(x, y, 'o', c='C1', markersize=5, markevery=3)
ax.plot(x2, y2, 'o', c='C2', markersize=5, markevery=3)
ax.plot(x3, y3, 'o', c='C3', markersize=5, markevery=3)
ax.plot(x4, y4, 'o', c='C4', markersize=5, markevery=3)
#ax.xaxis.set_major_locator(ticker.MultipleLocator(3))
plt.xlabel('k')
plt.ylabel('failprob')
plt.grid()
plt.legend(('p1=p2=p3=1/3', 'p1=0.2,p2=0.5,p3=0.2', 'p1=p2=p3=p4=0.25','p1=0.6,p2=p3=0.2'), loc="best", prop={'size': 10})
plt.savefig('FailprobIncreaseWithK_030303_01.png', bbox_inches='tight', dpi=300)

# %%
data = pd.read_csv('lorenzCurveAfter27840RoundsDriversNDvsWDF.csv')
x = data['%Drivers'] * 100  # plot percentages between 0 and 100
y1 = data[' %Util Total Equality'] * 100
y2 = data[' %Util ND'] * 100
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y1,'o', color="black", markersize=3, markevery=50)
ax.plot(x, y2, c='C1')
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax.yaxis.set_major_locator(ticker.MultipleLocator(10))
plt.grid()
plt.xlabel('\% Drivers')
plt.ylabel('\% Income')
plt.legend(('Equality', 'NDF'), loc="best", prop={'size': 10})
plt.savefig('lorenzCurveNDF_smallLegend.png', bbox_inches='tight', dpi=300)
plt.savefig('lorenzCurveNDF_smallLegend.eps', bbox_inches='tight', dpi=300)
plt.savefig('lorenzCurveNDF_smallLegend.pdf', bbox_inches='tight', dpi=300)

data = pd.read_csv('lorenzCurveAfter27840RoundsDriversNDvsWDF.csv')
x = data['%Drivers'] * 100  # plot percentages between 0 and 100
y1 = data[' %Util Total Equality'] * 100
y2 = data[' %Util ND'] * 100
y3 = data[' %Util WDF'] * 100
_, ax = plt.subplots()
ax.plot(x, y1,'o',color="black", markersize=3, markevery=50)
ax.plot(x, y2, c='C1')
ax.plot(x, y3, c='C2')
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
ax.yaxis.set_major_locator(ticker.MultipleLocator(10))
plt.grid()
plt.xlabel('\% Drivers')
plt.ylabel('\% Income')
plt.legend(('Equality', 'NDF', 'WDF'), loc="best", prop={'size': 10})
plt.savefig('lorenzCurveNDFvsWDF_smallLegend.png', bbox_inches='tight', dpi=300)
plt.savefig('lorenzCurveNDFvsWDF_smallLegend.eps', bbox_inches='tight', dpi=300)
plt.savefig('lorenzCurveNDFvsWDF_smallLegend.pdf', bbox_inches='tight', dpi=300)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import pandas as pd
import numpy as np

mpl.rcParams.update({'font.size': 22, 'lines.linewidth': 3, 'lines.markersize': 15, 'font.family': 'Times New Roman'})
    # avoid type 3 (i.e. bitmap) fonts in figures
mpl.rcParams['ps.useafm'] = True
mpl.rcParams['pdf.use14corefonts'] = True
mpl.rcParams['text.usetex'] = True

data = pd.read_csv('data_030303_01_2')
x = data['k']
y = data['adjustedAlpha']

_, ax = plt.subplots()
ax.plot(x, y, 'o', c='C1', markersize=5)
#ax.xaxis.set_major_locator(ticker.MultipleLocator(3))
plt.xlabel('k')
plt.ylabel('alpha')
plt.grid()
plt.legend(('p1=p2=p3=1/3',), loc="best", prop={'size': 10})
plt.savefig('alpha_030303_01.png', bbox_inches='tight', dpi=300)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import pandas as pd
import numpy as np

mpl.rcParams.update({'font.size': 22, 'lines.linewidth': 3, 'lines.markersize': 15, 'font.family': 'Times New Roman'})
    # avoid type 3 (i.e. bitmap) fonts in figures
mpl.rcParams['ps.useafm'] = True
mpl.rcParams['pdf.use14corefonts'] = True
mpl.rcParams['text.usetex'] = True

data = pd.read_csv('ndcgComparison.csv')
x = data['k']
y1 = data['dcg@kFair']
y2 = data['dcg@kUnfair']

_, ax = plt.subplots()
ax.plot(x, y1, c='C1', markersize=5)
ax.plot(x, y2, c='C2', markersize=5)
#ax.xaxis.set_major_locator(ticker.MultipleLocator(3))
plt.xlabel('k')
plt.ylabel('DCG@k')
plt.grid()
plt.legend(('multinomialFair','unfair'), loc="best", prop={'size': 10})
plt.savefig('dcgComparison.png', bbox_inches='tight', dpi=300)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import pandas as pd
import numpy as np

mpl.rcParams.update({'font.size': 22, 'lines.linewidth': 3, 'lines.markersize': 15, 'font.family': 'Times New Roman'})
    # avoid type 3 (i.e. bitmap) fonts in figures
mpl.rcParams['ps.useafm'] = True
mpl.rcParams['pdf.use14corefonts'] = True
mpl.rcParams['text.usetex'] = True

data = pd.read_csv('computationTimeRegression.csv')
x1 = data['k']
y1 = data['time']

data2 = pd.read_csv('computationTimeBinary.csv')
x2 = data2['k']
y2 = data2['time']

data3 = pd.read_csv('computationTimeBinarySteps10.csv')
x3 = data3['k']
y3 = data3['time']


_, ax = plt.subplots()
ax.plot(x1, y1, c='C1', markersize=5)
ax.plot(x2, y2, c='C2', markersize=5)
ax.plot(x3, y3, c='C3', markersize=5)
#ax.xaxis.set_major_locator(ticker.MultipleLocator(3))
plt.xlabel('k')
plt.ylabel('seconds')
plt.grid()
plt.legend(('regression','binary', 'binary with pre-adjustment'), loc="best", prop={'size': 10})
plt.savefig('computationTime.png', bbox_inches='tight', dpi=300)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from mpl_toolkits import mplot3d

import pandas as pd
import numpy as np

mpl.rcParams.update({'font.size': 15, 'lines.linewidth': 3, 'lines.markersize': 15, 'font.family': 'Times New Roman'})
    # avoid type 3 (i.e. bitmap) fonts in figures
mpl.rcParams['ps.useafm'] = True
mpl.rcParams['pdf.use14corefonts'] = True
mpl.rcParams['text.usetex'] = True

data = pd.read_csv('data_alpha_p_k50_a15.csv')
x1 = data['p1']
y1 = data['alpha']
z1 = data['p2']

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(x1, z1, y1, c='black', cmap='none')
#ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
#ax.yaxis.set_major_locator(ticker.MultipleLocator(5))
#ax.zaxis.set_major_locator(ticker.MultipleLocator(5))
ax.set_xlabel('p1')
ax.set_ylabel('p2')
ax.set_zlabel('alpha')
ax.view_init(22, 66)
plt.grid()
ax.set_zlim3d(0, 0.008)
plt.legend(('regression',), loc="best", prop={'size': 10})
plt.savefig('alphaDependentOnPa015.png', bbox_inches='tight', dpi=300)
